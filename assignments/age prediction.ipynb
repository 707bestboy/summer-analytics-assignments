# %%
import pandas as pd

# %%
train = pd.read_csv("C:\\Users\\gehlo\\Downloads\\Train_Data.csv")
test = pd.read_csv("C:\\Users\\gehlo\Downloads\\Test_Data.csv")

# %%
train.drop(columns=['SEQN'], inplace=True)
test.drop(columns=['SEQN'], inplace=True)

# %%
test.isnull().sum()
# Out:
# SEQN        2
# RIAGENDR    2
# PAQ605      1
# BMXBMI      1
# LBXGLU      1
# DIQ010      1
# LBXGLT      2
# LBXIN       1
# dtype: int64

# %%
test.head()
# Out:
#       SEQN  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  LBXGLT  LBXIN
# 0  77017.0       1.0     1.0    32.2    96.0     2.0   135.0  15.11
# 1  75580.0       2.0     2.0    26.3   100.0     2.0   141.0  15.26
# 2  73820.0       1.0     2.0    28.6   107.0     2.0   136.0   8.82
# 3  80489.0       2.0     1.0    22.1    93.0     2.0   111.0  12.13
# 4  82047.0       1.0     1.0    24.7    91.0     2.0   105.0   3.12

# %%
test.describe()
# Out:
#                SEQN    RIAGENDR      PAQ605      BMXBMI      LBXGLU  \
# count    310.000000  310.000000  311.000000  311.000000  311.000000
# mean   78717.490323    1.522581    1.803859   27.810611  100.067524
# std     2905.999069    0.500297    0.397717    6.717031   23.920539
# min    73659.000000    1.000000    1.000000   15.900000   69.000000
# 25%    76006.500000    1.000000    2.000000   22.950000   92.000000
# 50%    79036.500000    2.000000    2.000000   26.800000   97.000000
# 75%    81167.000000    2.000000    2.000000   30.900000  103.000000
# max    83694.000000    2.000000    2.000000   54.900000  368.000000
#
#            DIQ010      LBXGLT       LBXIN
# count  311.000000  310.000000  311.000000
# mean     2.019293  114.241935   11.666463
# std      0.159477   52.356101    9.570438
# min      1.000000   43.000000    1.040000
# 25%      2.000000   86.000000    6.120000
# 50%      2.000000  102.500000    9.220000
# 75%      2.000000  128.750000   14.185000
# ...

# %%
train.describe()
# Out:
#                SEQN     RIAGENDR       PAQ605       BMXBMI       LBXGLU  \
# count   1954.000000  1948.000000  1953.000000  1948.000000  1953.000000
# mean   78683.621801     1.510267     1.825397    27.965400    99.491039
# std     2924.115709     0.500023     0.399449     7.327616    16.774665
# min    73564.000000     1.000000     1.000000    14.500000    63.000000
# 25%    76194.000000     1.000000     2.000000    22.800000    91.000000
# 50%    78717.000000     2.000000     2.000000    26.800000    97.000000
# 75%    81217.000000     2.000000     2.000000    31.300000   104.000000
# max    83727.000000     2.000000     7.000000    70.100000   405.000000
#
#             DIQ010       LBXGLT        LBXIN
# count  1948.000000  1955.000000  1957.000000
# mean      2.015914   115.150384    11.862892
# std       0.187579    46.271615     9.756713
# min       1.000000    40.000000     0.140000
# 25%       2.000000    87.000000     5.800000
# 50%       2.000000   105.000000     9.030000
# ...

# %%
train.head()
# Out:
#       SEQN  RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  LBXGLT  LBXIN age_group
# 0  73564.0       2.0     2.0    35.7   110.0     2.0   150.0  14.91     Adult
# 1  73568.0       2.0     2.0    20.3    89.0     2.0    80.0   3.85     Adult
# 2  73576.0       1.0     2.0    23.2    89.0     2.0    68.0   6.14     Adult
# 3  73577.0       1.0     2.0    28.9   104.0     NaN    84.0  16.15     Adult
# 4  73580.0       2.0     1.0    35.9   103.0     2.0    81.0  10.92     Adult

# %%
train['age_group'].unique()
# Out:
# array(['Adult', 'Senior', nan], dtype=object)

# %%
train.isnull().sum()
# Out:
# SEQN         12
# RIAGENDR     18
# PAQ605       13
# BMXBMI       18
# LBXGLU       13
# DIQ010       18
# LBXGLT       11
# LBXIN         9
# age_group    14
# dtype: int64

# %%
train.shape
# Out:
# (1966, 9)

# %%
train = train.dropna()

# %%
train.shape
# Out:
# (1841, 9)

# %%
train.columns.tolist()
# Out:
# ['SEQN',
#  'RIAGENDR',
#  'PAQ605',
#  'BMXBMI',
#  'LBXGLU',
#  'DIQ010',
#  'LBXGLT',
#  'LBXIN',
#  'age_group']

# %%
import matplotlib.pyplot as plt

# %%
train['age_group'].hist()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
train['age_group'] = LabelEncoder().fit_transform(train['age_group'])  # example

# %%
train.head()
# Out:
#    RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  LBXGLT  LBXIN  age_group
# 0       2.0     2.0    35.7   110.0     2.0   150.0  14.91          0
# 1       2.0     2.0    20.3    89.0     2.0    80.0   3.85          0
# 2       1.0     2.0    23.2    89.0     2.0    68.0   6.14          0
# 4       2.0     1.0    35.9   103.0     2.0    81.0  10.92          0
# 5       1.0     2.0    23.6   110.0     2.0   100.0   6.08          0

# %%
X = train.drop(['age_group'], axis=1)
y = train['age_group']

# %%
y.value_counts(normalize=True)
# Out:
# age_group
# Adult     0.839139
# Senior    0.160861
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in X.columns:
    if X[col].dtype != 'object':  # Skip categorical for now
        plt.figure(figsize=(6, 4))
        sns.boxplot(x=y, y=X[col])
        plt.title(f"{col} vs Target")
        plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

for col in X_train.columns:
    model = DecisionTreeClassifier(max_depth=2)
    model.fit(X_train[[col]], y_train)
    preds = model.predict(X_train[[col]])
    acc = accuracy_score(y_train, preds)
    print(f"{col}: {acc:.4f}")

# %%
X.head()
# Out:
#    RIAGENDR  PAQ605  BMXBMI  LBXGLU  DIQ010  LBXGLT  LBXIN
# 0       2.0     2.0    35.7   110.0     2.0   150.0  14.91
# 1       2.0     2.0    20.3    89.0     2.0    80.0   3.85
# 2       1.0     2.0    23.2    89.0     2.0    68.0   6.14
# 4       2.0     1.0    35.9   103.0     2.0    81.0  10.92
# 5       1.0     2.0    23.6   110.0     2.0   100.0   6.08

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 4    0
# 5    0
# Name: age_group, dtype: int64

# %%
test = test.fillna(test.mean())

# %%
test.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X) 
X_test_scaled = scaler.transform(test)

# %%
# from sklearn.ensemble import RandomForestClassifier

# model = RandomForestClassifier(random_state=42)
# model.fit(X_scaled, y)  # or use X_scaled if you scaled in Step 1

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    - -------------------------------------- 7.3/150.0 MB 37.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 16.0/150.0 MB 40.2 MB/s eta 0:00:04
#    ------ --------------------------------- 23.9/150.0 MB 38.7 MB/s eta 0:00:04
#    -------- ------------------------------- 33.0/150.0 MB 40.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 41.9/150.0 MB 41.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 42.7/150.0 MB 34.8 MB/s eta 0:00:04
#    ------------- -------------------------- 51.1/150.0 MB 35.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 61.9/150.0 MB 37.9 MB/s eta 0:00:03
#    ------------------- -------------------- 73.1/150.0 MB 39.8 MB/s eta 0:00:02
#    --------------------- ------------------ 78.9/150.0 MB 38.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 83.6/150.0 MB 37.0 MB/s eta 0:00:02
# ...

# %%
import xgboost as xgb
model = xgb.XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.5,
    reg_lambda=1,
    random_state=42
)

# %%
from sklearn.utils import class_weight
cw = class_weight.compute_sample_weight('balanced', y)
model.fit(X_scaled, y, sample_weight=cw)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_test_pred = model.predict(X_test_scaled)  # or X_test_scaled if scaled

# %%
import pandas as pd

output = pd.DataFrame({
    'age_group': y_test_pred
})
output.to_csv('C:\\Users\\gehlo\Downloads\\predictions6.csv', index=False)
